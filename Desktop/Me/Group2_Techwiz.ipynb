# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Collection

# %%
train_data = pd.read_csv('Train.csv')
train_data
# Out:
#                  ID  country_code  region   age  FQ1  FQ2  FQ3  FQ4  FQ5  FQ6  \
# 0       ID_000J8GTZ             1       6  35.0    2  NaN  NaN    2  NaN  NaN
# 1       ID_000QLXZM            32       7  70.0    2  NaN  NaN    2  NaN  NaN
# 2       ID_001728I2            71       7  22.0    2  1.0  NaN    2  NaN  NaN
# 3       ID_001R7IDN            48       3  27.0    1  NaN  NaN    2  NaN  2.0
# 4       ID_0029QKF8            25       0  79.0    2  NaN  NaN    2  NaN  NaN
# ...             ...           ...     ...   ...  ...  ...  ...  ...  ...  ...
# 108441  ID_ZZYY7RTO           111       4  23.0    2  NaN  NaN    2  NaN  2.0
# 108442  ID_ZZYZTTC6            77       4  60.0    1  NaN  NaN    2  NaN  NaN
# 108443  ID_ZZZ3OW3S            42       2  59.0    1  NaN  1.0    1  NaN  NaN
# 108444  ID_ZZZLDXE8            57       7  79.0    1  NaN  NaN    2  NaN  1.0
# 108445  ID_ZZZMYW1F           110       2  74.0    2  1.0  2.0    2  NaN  1.0
#
# ...

# %%
train_data.head()
# Out:
#             ID  country_code  region   age  FQ1  FQ2  FQ3  FQ4  FQ5  FQ6  ...  \
# 0  ID_000J8GTZ             1       6  35.0    2  NaN  NaN    2  NaN  NaN  ...
# 1  ID_000QLXZM            32       7  70.0    2  NaN  NaN    2  NaN  NaN  ...
# 2  ID_001728I2            71       7  22.0    2  1.0  NaN    2  NaN  NaN  ...
# 3  ID_001R7IDN            48       3  27.0    1  NaN  NaN    2  NaN  2.0  ...
# 4  ID_0029QKF8            25       0  79.0    2  NaN  NaN    2  NaN  NaN  ...
#
#    FQ27  FQ28  FQ29  FQ30  FQ31  FQ32  FQ33  FQ34  FQ37  Target
# 0   NaN   NaN   1.0   NaN   NaN   NaN   1.0   1.0     0       0
# 1   NaN   NaN   2.0   NaN   NaN   NaN   1.0   2.0     0       0
# 2   NaN   NaN   2.0   NaN   NaN   NaN   2.0   1.0     1       0
# 3   NaN   NaN   NaN   NaN   NaN   2.0   1.0   1.0     1       0
# 4   NaN   NaN   2.0   NaN   NaN   2.0   1.0   1.0     1       0
#
# [5 rows x 42 columns]

# %%
train_data.describe()
# Out:
#         country_code         region            age            FQ1  \
# count  108446.000000  108446.000000  108124.000000  108446.000000
# mean       68.544953       2.894242      41.857395       1.563294
# std        41.529264       2.286505      17.876105       0.530077
# min         0.000000      -1.000000      15.000000       1.000000
# 25%        33.000000       1.000000      27.000000       1.000000
# 50%        65.000000       3.000000      39.000000       2.000000
# 75%       105.000000       4.000000      55.000000       2.000000
# max       143.000000       7.000000      99.000000       4.000000
#
#                 FQ2           FQ3            FQ4           FQ5           FQ6  \
# count  49124.000000  46218.000000  108446.000000  21185.000000  60659.000000
# mean       1.063716      1.299710       1.824622      1.160113      1.223907
# std        0.288075      0.468503       0.435942      0.383827      0.450140
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108446 entries, 0 to 108445
# Data columns (total 42 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            108446 non-null  object
#  1   country_code  108446 non-null  int64
#  2   region        108446 non-null  int64
#  3   age           108124 non-null  float64
#  4   FQ1           108446 non-null  int64
#  5   FQ2           49124 non-null   float64
#  6   FQ3           46218 non-null   float64
#  7   FQ4           108446 non-null  int64
#  8   FQ5           21185 non-null   float64
#  9   FQ6           60659 non-null   float64
#  10  FQ7           60620 non-null   float64
#  11  FQ8           108446 non-null  int64
#  12  FQ9           108446 non-null  int64
#  13  FQ10          108446 non-null  int64
#  14  FQ11          83876 non-null   float64
#  15  FQ12          108446 non-null  int64
#  16  FQ13          108446 non-null  int64
# ...

# %%
test_data = pd.read_csv('Test.csv')
test_data
# Out:
#                 ID  country_code  region   age  FQ1  FQ2  FQ3  FQ4  FQ5  FQ6  \
# 0      ID_000YI58E            39       2  22.0    2  NaN  NaN    2  NaN  1.0
# 1      ID_001SP4JF            30       2  62.0    1  NaN  NaN    2  NaN  1.0
# 2      ID_001VOF6S            65       4  35.0    2  1.0  NaN    1  1.0  NaN
# 3      ID_0030LULG           123       0  24.0    2  1.0  NaN    2  NaN  1.0
# 4      ID_0037PZ3R            67       2  25.0    2  NaN  NaN    1  NaN  NaN
# ...            ...           ...     ...   ...  ...  ...  ...  ...  ...  ...
# 46472  ID_ZZYOTVBJ           112       3  38.0    1  1.0  NaN    2  NaN  NaN
# 46473  ID_ZZYSX122            82       2  77.0    2  1.0  1.0    2  NaN  1.0
# 46474  ID_ZZYXQDSD            93       5  26.0    2  NaN  NaN    2  NaN  1.0
# 46475  ID_ZZZH9SS4             6       7  59.0    2  1.0  NaN    2  NaN  1.0
# 46476  ID_ZZZTLL7U           105       0  24.0    2  NaN  NaN    2  1.0  NaN
#
# ...

# %%
test_data.describe()
# Out:
#        country_code        region           age           FQ1           FQ2  \
# count  46477.000000  46477.000000  46348.000000  46477.000000  20801.000000
# mean      68.364223      2.904017     41.806227      1.561009      1.062257
# std       41.509763      2.282829     17.997078      0.528397      0.283893
# min        0.000000     -1.000000     15.000000      1.000000      1.000000
# 25%       33.000000      1.000000     27.000000      1.000000      1.000000
# 50%       65.000000      3.000000     39.000000      2.000000      1.000000
# 75%      104.000000      4.000000     55.000000      2.000000      1.000000
# max      143.000000      7.000000     99.000000      4.000000      4.000000
#
#                 FQ3           FQ4          FQ5           FQ6           FQ7  \
# count  19928.000000  46477.000000  8913.000000  25878.000000  25917.000000
# mean       1.297069      1.824537     1.157523      1.222467      1.206621
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46477 entries, 0 to 46476
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            46477 non-null  object
#  1   country_code  46477 non-null  int64
#  2   region        46477 non-null  int64
#  3   age           46348 non-null  float64
#  4   FQ1           46477 non-null  int64
#  5   FQ2           20801 non-null  float64
#  6   FQ3           19928 non-null  float64
#  7   FQ4           46477 non-null  int64
#  8   FQ5           8913 non-null   float64
#  9   FQ6           25878 non-null  float64
#  10  FQ7           25917 non-null  float64
#  11  FQ8           46477 non-null  int64
#  12  FQ9           46477 non-null  int64
#  13  FQ10          46477 non-null  int64
#  14  FQ11          35912 non-null  float64
#  15  FQ12          46477 non-null  int64
#  16  FQ13          46477 non-null  int64
#  17  FQ14          46477 non-null  int64
# ...

# %% [markdown]
# # Data Wrangling

# %%
train_data.isnull().any()
# Out:
# ID              False
# country_code    False
# region          False
# age              True
# FQ1             False
# FQ2              True
# FQ3              True
# FQ4             False
# FQ5              True
# FQ6              True
# FQ7              True
# FQ8             False
# FQ9             False
# FQ10            False
# FQ11             True
# FQ12            False
# FQ13            False
# FQ14            False
# FQ15            False
# FQ16            False
# FQ17             True
# FQ18            False
# FQ19             True
# FQ20             True
# FQ21             True
# FQ22            False
# FQ23            False
# FQ24             True
# FQ35             True
# FQ36             True
# FQ25            False
# FQ26            False
# FQ27             True
# FQ28             True
# FQ29             True
# FQ30             True
# FQ31             True
# FQ32             True
# FQ33             True
# FQ34             True
# FQ37            False
# ...

# %%
train_data['age'].isnull().any()
# Out:
# True

# %%
# age = train_data.isnull().value_counts()
# age

# %%
missing = train_data.isnull().mean() * 100
missing
# Out:
# ID               0.000000
# country_code     0.000000
# region           0.000000
# age              0.296922
# FQ1              0.000000
# FQ2             54.701879
# FQ3             57.381554
# FQ4              0.000000
# FQ5             80.464932
# FQ6             44.065249
# FQ7             44.101212
# FQ8              0.000000
# FQ9              0.000000
# FQ10             0.000000
# FQ11            22.656437
# FQ12             0.000000
# FQ13             0.000000
# FQ14             0.000000
# FQ15             0.000000
# FQ16             0.000000
# FQ17            89.536728
# FQ18             0.000000
# FQ19            43.714844
# FQ20            22.756948
# FQ21            22.716375
# FQ22             0.000000
# FQ23             0.000000
# FQ24            64.561164
# FQ35            76.127289
# FQ36            89.411320
# FQ25             0.000000
# FQ26             0.000000
# FQ27            97.049223
# FQ28            98.611290
# FQ29            22.623241
# ...

# %%
train_data.isnull().mean().round(4).mul(100).sort_values(ascending=False)
# Out:
# FQ31            99.20
# FQ28            98.61
# FQ30            98.05
# FQ27            97.05
# FQ17            89.54
# FQ36            89.41
# FQ5             80.46
# FQ35            76.13
# FQ24            64.56
# FQ3             57.38
# FQ2             54.70
# FQ7             44.10
# FQ6             44.07
# FQ32            43.94
# FQ19            43.71
# FQ34            29.32
# FQ20            22.76
# FQ21            22.72
# FQ11            22.66
# FQ29            22.62
# age              0.30
# FQ33             0.00
# FQ37             0.00
# FQ25             0.00
# FQ26             0.00
# ID               0.00
# FQ18             0.00
# FQ23             0.00
# FQ22             0.00
# country_code     0.00
# FQ16             0.00
# FQ15             0.00
# FQ14             0.00
# FQ13             0.00
# FQ12             0.00
# FQ10             0.00
# FQ9              0.00
# FQ8              0.00
# FQ4              0.00
# FQ1              0.00
# region           0.00
# ...

# %%
train_data['Target'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
all_data = pd.concat([train_data, test_data])
all_data
# Out:
#                 ID  country_code  region   age  FQ1  FQ2  FQ3  FQ4  FQ5  FQ6  \
# 0      ID_000J8GTZ             1       6  35.0    2  NaN  NaN    2  NaN  NaN
# 1      ID_000QLXZM            32       7  70.0    2  NaN  NaN    2  NaN  NaN
# 2      ID_001728I2            71       7  22.0    2  1.0  NaN    2  NaN  NaN
# 3      ID_001R7IDN            48       3  27.0    1  NaN  NaN    2  NaN  2.0
# 4      ID_0029QKF8            25       0  79.0    2  NaN  NaN    2  NaN  NaN
# ...            ...           ...     ...   ...  ...  ...  ...  ...  ...  ...
# 46472  ID_ZZYOTVBJ           112       3  38.0    1  1.0  NaN    2  NaN  NaN
# 46473  ID_ZZYSX122            82       2  77.0    2  1.0  1.0    2  NaN  1.0
# 46474  ID_ZZYXQDSD            93       5  26.0    2  NaN  NaN    2  NaN  1.0
# 46475  ID_ZZZH9SS4             6       7  59.0    2  1.0  NaN    2  NaN  1.0
# 46476  ID_ZZZTLL7U           105       0  24.0    2  NaN  NaN    2  1.0  NaN
#
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154923 entries, 0 to 46476
# Data columns (total 42 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            154923 non-null  object
#  1   country_code  154923 non-null  int64
#  2   region        154923 non-null  int64
#  3   age           154472 non-null  float64
#  4   FQ1           154923 non-null  int64
#  5   FQ2           69925 non-null   float64
#  6   FQ3           66146 non-null   float64
#  7   FQ4           154923 non-null  int64
#  8   FQ5           30098 non-null   float64
#  9   FQ6           86537 non-null   float64
#  10  FQ7           86537 non-null   float64
#  11  FQ8           154923 non-null  int64
#  12  FQ9           154923 non-null  int64
#  13  FQ10          154923 non-null  int64
#  14  FQ11          119788 non-null  float64
#  15  FQ12          154923 non-null  int64
#  16  FQ13          154923 non-null  int64
# ...

# %%
all_data.describe()
# Out:
#         country_code         region            age            FQ1  \
# count  154923.000000  154923.000000  154472.000000  154923.000000
# mean       68.490734       2.897175      41.842043       1.562609
# std        41.523363       2.285400      17.912444       0.529573
# min         0.000000      -1.000000      15.000000       1.000000
# 25%        33.000000       1.000000      27.000000       1.000000
# 50%        65.000000       3.000000      39.000000       2.000000
# 75%       105.000000       4.000000      55.000000       2.000000
# max       143.000000       7.000000      99.000000       4.000000
#
#                 FQ2           FQ3            FQ4           FQ5           FQ6  \
# count  69925.000000  66146.000000  154923.000000  30098.000000  86537.000000
# mean       1.063282      1.298915       1.824597      1.159346      1.223477
# std        0.286836      0.468202       0.436026      0.381386      0.449687
# ...

# %%
all_data.isnull().sum().sort_values()
# Out:
# ID                   0
# FQ23                 0
# FQ18                 0
# FQ37                 0
# FQ16                 0
# FQ15                 0
# FQ14                 0
# FQ13                 0
# FQ12                 0
# FQ10                 0
# FQ8                  0
# FQ9                  0
# FQ26                 0
# FQ4                  0
# FQ1                  0
# region               0
# country_code         0
# FQ25                 0
# FQ22                 0
# FQ33                 2
# age                451
# FQ21             35135
# FQ11             35135
# FQ29             35135
# FQ20             35135
# FQ34             45135
# Target           46477
# FQ19             67764
# FQ32             68127
# FQ7              68386
# FQ6              68386
# FQ2              84998
# FQ3              88777
# FQ24             99926
# FQ35            117982
# FQ5             124825
# FQ36            138540
# FQ17            138698
# FQ27            150280
# FQ30            151932
# ...

# %%
x  = all_data.columns
y = (all_data.isnull().mean().round(4).mul(100).sort_values(ascending=True))

# y = (train_data.isnull().sort_values(ascending=False))
plt.figure(figsize=(10,8),dpi=80)
plt.plot(x, y)
plt.xticks(rotation=90)
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Percentage of Missing Data Values')
plt.grid(linestyle='-')
plt.show()

# %%
z = all_data.std()
plt.figure(figsize=(10,8),dpi=80)
plt.plot(z)
plt.xticks(rotation=90)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
v= all_data.std(axis=None, skipna=None, level=None, ddof=1, numeric_only=None)
v
# Out:
# country_code    41.523363
# region           2.285400
# age             17.912444
# FQ1              0.529573
# FQ2              0.286836
# FQ3              0.468202
# FQ4              0.436026
# FQ5              0.381386
# FQ6              0.449687
# FQ7              0.440323
# FQ8              0.382922
# FQ9              0.449564
# FQ10             0.465978
# FQ11             0.380646
# FQ12             0.364006
# FQ13             0.329371
# FQ14             0.278379
# FQ15             0.356875
# FQ16             0.444624
# FQ17             0.500965
# FQ18             0.578901
# FQ19             1.271272
# FQ20             0.427413
# FQ21             0.450576
# FQ22             0.523944
# FQ23             0.504065
# FQ24             0.455070
# FQ35             0.532363
# FQ36             0.482214
# FQ25             0.383102
# FQ26             0.365989
# FQ27             0.562124
# FQ28             0.496468
# FQ29             0.383022
# FQ30             0.549524
# ...

# %%
all_data.describe()
# Out:
#         country_code         region            age            FQ1  \
# count  154923.000000  154923.000000  154472.000000  154923.000000
# mean       68.490734       2.897175      41.842043       1.562609
# std        41.523363       2.285400      17.912444       0.529573
# min         0.000000      -1.000000      15.000000       1.000000
# 25%        33.000000       1.000000      27.000000       1.000000
# 50%        65.000000       3.000000      39.000000       2.000000
# 75%       105.000000       4.000000      55.000000       2.000000
# max       143.000000       7.000000      99.000000       4.000000
#
#                 FQ2           FQ3            FQ4           FQ5           FQ6  \
# count  69925.000000  66146.000000  154923.000000  30098.000000  86537.000000
# mean       1.063282      1.298915       1.824597      1.159346      1.223477
# std        0.286836      0.468202       0.436026      0.381386      0.449687
# ...

# %%
all_data.isnull().sum().sort_values()
# Out:
# ID                   0
# FQ23                 0
# FQ18                 0
# FQ37                 0
# FQ16                 0
# FQ15                 0
# FQ14                 0
# FQ13                 0
# FQ12                 0
# FQ10                 0
# FQ8                  0
# FQ9                  0
# FQ26                 0
# FQ4                  0
# FQ1                  0
# region               0
# country_code         0
# FQ25                 0
# FQ22                 0
# FQ33                 2
# age                451
# FQ21             35135
# FQ11             35135
# FQ29             35135
# FQ20             35135
# FQ34             45135
# Target           46477
# FQ19             67764
# FQ32             68127
# FQ7              68386
# FQ6              68386
# FQ2              84998
# FQ3              88777
# FQ24             99926
# FQ35            117982
# FQ5             124825
# FQ36            138540
# FQ17            138698
# FQ27            150280
# FQ30            151932
# ...

# %%
# corrMatrix = all_data.corr()
# a = all_data.columns
# figure(figsize=(20,20),dpi=80)
# sns.heatmap(corrMatrix, annot=True)
# plt.show()

# %%
all_data["age"].unique()
# Out:
# array([35., 70., 22., 27., 79., 69., 58., 32., 59., 60., 26., 54., 34.,
#        47., 33., 36., 75., 76., 52., 28., 87., 77., 53., 19., 65., 30.,
#        78., 73., 23., 45., 41., 64., 44., 67., 18., 51., 46., 61., 88.,
#        25., 38., 62., 43., 37., 24., 39., 20., 15., 21., 16., 40., 66.,
#        29., 56., 80., 83., 63., 84., 72., 55., 17., 81., 50., 57., nan,
#        85., 48., 31., 74., 68., 42., 49., 89., 71., 82., 90., 98., 86.,
#        92., 91., 93., 99., 96., 95., 97., 94.])

# %%
all_data["age"].fillna(int(all_data["age"].mode()), inplace=True)

# %%
all_data["FQ11"].unique()
# Out:
# array([ 2.,  4.,  1., nan,  3.])

# %%
all_data["FQ11"].fillna(int(all_data["FQ11"].mode()), inplace=True)

# %%
all_data["FQ20"].unique()
# Out:
# array([ 2.,  1., nan,  3.,  4.])

# %%
all_data["FQ20"].fillna(all_data["FQ20"].mean(), inplace=True)

# %%
all_data["FQ21"].fillna(all_data["FQ21"].mode(), inplace=True)

# %%
all_data["FQ29"].fillna(all_data["FQ29"].mode(), inplace=True)

# %%
all_data["FQ19"].fillna(all_data["FQ19"].mode(), inplace=True)

# %%
all_data["FQ32"].fillna(all_data["FQ32"].mode(), inplace=True)

# %%
all_data["FQ6"].fillna(all_data["FQ6"].mode(), inplace=True)

# %%
all_data["FQ7"].fillna(all_data["FQ7"].mode(), inplace=True)

# %%
all_data["FQ3"].fillna(all_data["FQ3"].mode(), inplace=True)

# %%
all_data["FQ33"].fillna(all_data["FQ33"].mean(), inplace=True)

# %%
all_data["FQ17"].fillna(all_data["FQ17"].mean(), inplace=True)

# %%
all_data["FQ27"].fillna(all_data["FQ27"].mean(), inplace=True)

# %%
all_data["FQ30"].fillna(all_data["FQ30"].median(), inplace=True)

# %%
all_data["FQ31"].fillna(all_data["FQ31"].median(), inplace=True)

# %%
all_data["FQ34"].fillna(int(all_data["FQ34"].median()), inplace=True)

# %%
all_data["FQ35"].fillna(all_data["FQ35"].mean(), inplace=True)

# %%
all_data["FQ5"].fillna(all_data["FQ5"].mean(), inplace=True)

# %%
all_data["FQ28"].fillna(all_data["FQ28"].mean(), inplace=True)

# %%
all_data["FQ2"].unique()
# Out:
# array([nan,  1.,  2.,  4.,  3.])

# %%
all_data["Target"].fillna(all_data["Target"].mean(), inplace=True)

# %%
all_data["FQ24"].fillna(all_data["FQ24"].mean(), inplace=True)

# %%
all_data["FQ2"].fillna(all_data["FQ2"].mean(), inplace=True)

# %%
all_data.isnull().sum().sort_values()
# Out:
# ID                   0
# FQ37                 0
# FQ18                 0
# FQ20                 0
# FQ22                 0
# FQ23                 0
# FQ24                 0
# FQ35                 0
# FQ25                 0
# FQ26                 0
# FQ27                 0
# FQ28                 0
# FQ30                 0
# FQ31                 0
# FQ33                 0
# FQ34                 0
# FQ16                 0
# FQ15                 0
# FQ17                 0
# FQ13                 0
# country_code         0
# region               0
# age                  0
# FQ1                  0
# FQ2                  0
# FQ4                  0
# FQ14                 0
# FQ5                  0
# FQ8                  0
# FQ9                  0
# FQ10                 0
# FQ11                 0
# FQ12                 0
# Target               0
# FQ21             35134
# FQ29             35134
# FQ19             67764
# FQ32             68126
# FQ6              68385
# FQ7              68385
# ...

# %%
def fill_with_mean(column, dataset=all_data):
  dataset[column].fillna(dataset[column].mean(), inplace=True)

# %%
feature_missing = all_data.columns[all_data.isna().any()]

for column in feature_missing:
  fill_with_mean(column)

# %%
all_data.isnull().sum().sort_values()
# Out:
# ID              0
# FQ20            0
# FQ21            0
# FQ22            0
# FQ23            0
# FQ24            0
# FQ35            0
# FQ36            0
# FQ25            0
# FQ26            0
# FQ27            0
# FQ28            0
# FQ29            0
# FQ30            0
# FQ31            0
# FQ32            0
# FQ33            0
# FQ34            0
# FQ19            0
# FQ18            0
# FQ17            0
# FQ16            0
# country_code    0
# region          0
# age             0
# FQ1             0
# FQ2             0
# FQ3             0
# FQ4             0
# FQ5             0
# FQ37            0
# FQ6             0
# FQ8             0
# FQ9             0
# FQ10            0
# FQ11            0
# FQ12            0
# FQ13            0
# FQ14            0
# FQ15            0
# FQ7             0
# Target          0
# dtype: int64

# %%
all_data.columns
# Out:
# Index(['ID', 'country_code', 'region', 'age', 'FQ1', 'FQ2', 'FQ3', 'FQ4',
#        'FQ5', 'FQ6', 'FQ7', 'FQ8', 'FQ9', 'FQ10', 'FQ11', 'FQ12', 'FQ13',
#        'FQ14', 'FQ15', 'FQ16', 'FQ17', 'FQ18', 'FQ19', 'FQ20', 'FQ21', 'FQ22',
#        'FQ23', 'FQ24', 'FQ35', 'FQ36', 'FQ25', 'FQ26', 'FQ27', 'FQ28', 'FQ29',
#        'FQ30', 'FQ31', 'FQ32', 'FQ33', 'FQ34', 'FQ37', 'Target'],
#       dtype='object')

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154923 entries, 0 to 46476
# Data columns (total 42 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            154923 non-null  object
#  1   country_code  154923 non-null  int64
#  2   region        154923 non-null  int64
#  3   age           154923 non-null  float64
#  4   FQ1           154923 non-null  int64
#  5   FQ2           154923 non-null  float64
#  6   FQ3           154923 non-null  float64
#  7   FQ4           154923 non-null  int64
#  8   FQ5           154923 non-null  float64
#  9   FQ6           154923 non-null  float64
#  10  FQ7           154923 non-null  float64
#  11  FQ8           154923 non-null  int64
#  12  FQ9           154923 non-null  int64
#  13  FQ10          154923 non-null  int64
#  14  FQ11          154923 non-null  float64
#  15  FQ12          154923 non-null  int64
#  16  FQ13          154923 non-null  int64
# ...

# %%
all_data.describe()
# Out:
#         country_code         region            age            FQ1  \
# count  154923.000000  154923.000000  154923.000000  154923.000000
# mean       68.490734       2.897175      41.807569       1.562609
# std        41.523363       2.285400      17.897728       0.529573
# min         0.000000      -1.000000      15.000000       1.000000
# 25%        33.000000       1.000000      27.000000       1.000000
# 50%        65.000000       3.000000      39.000000       2.000000
# 75%       105.000000       4.000000      55.000000       2.000000
# max       143.000000       7.000000      99.000000       4.000000
#
#                  FQ2            FQ3            FQ4            FQ5  \
# count  154923.000000  154923.000000  154923.000000  154923.000000
# mean        1.063282       1.298905       1.824597       1.159346
# std         0.192704       0.305934       0.436026       0.168101
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
all_data.columns
# Out:
# Index(['ID', 'country_code', 'region', 'age', 'FQ1', 'FQ2', 'FQ3', 'FQ4',
#        'FQ5', 'FQ6', 'FQ7', 'FQ8', 'FQ9', 'FQ10', 'FQ11', 'FQ12', 'FQ13',
#        'FQ14', 'FQ15', 'FQ16', 'FQ17', 'FQ18', 'FQ19', 'FQ20', 'FQ21', 'FQ22',
#        'FQ23', 'FQ24', 'FQ35', 'FQ36', 'FQ25', 'FQ26', 'FQ27', 'FQ28', 'FQ29',
#        'FQ30', 'FQ31', 'FQ32', 'FQ33', 'FQ34', 'FQ37', 'Target'],
#       dtype='object')

# %%
all_data.drop(columns=['ID','country_code','FQ24','FQ32','FQ35','FQ36','FQ29','FQ28','FQ27','FQ26','FQ25'], inplace=True)

# %%
all_data.columns
# Out:
# Index(['region', 'age', 'FQ1', 'FQ2', 'FQ3', 'FQ4', 'FQ5', 'FQ6', 'FQ7', 'FQ8',
#        'FQ9', 'FQ10', 'FQ11', 'FQ12', 'FQ13', 'FQ14', 'FQ15', 'FQ16', 'FQ17',
#        'FQ18', 'FQ19', 'FQ20', 'FQ21', 'FQ22', 'FQ23', 'FQ30', 'FQ31', 'FQ33',
#        'FQ34', 'FQ37', 'Target'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
features = ['region', 'FQ10', 'FQ18', 'FQ12']
fig=plt.subplots(figsize=(12, 9))

for index,feature in enumerate(features):
    plt.subplot(2,2,index+1)
    plt.subplots_adjust(hspace=1.0)
    sns.histplot(x=all_data[feature])
    
features = ["FQ1","FQ3","FQ6","FQ7"]
fig=plt.subplots(figsize=(12, 9))

for index,feature in enumerate(features):
    plt.subplot(2,2,index+1)
    plt.subplots_adjust(hspace=1.0)
    sns.histplot(x=all_data[feature])

features = ["FQ33","FQ31","FQ20","FQ21"]
fig=plt.subplots(figsize=(12, 9))

for index,feature in enumerate(features):
    plt.subplot(2,2,index+1)
    plt.subplots_adjust(hspace=1.0)
    sns.histplot(x=all_data[feature])

# %%
#those who have a bank account against those that don't 
sns.countplot(x ='FQ37', data = all_data)
# Out:
# <AxesSubplot:xlabel='FQ37', ylabel='count'>

# %%
#who has a mobile phone against those who don't
sns.countplot(x ='FQ33', data = all_data)
# Out:
# <AxesSubplot:xlabel='FQ33', ylabel='count'>

# %%
#phone and bank account
sns.countplot(x ='FQ37', hue ='FQ33', data = all_data)
# Out:
# <AxesSubplot:xlabel='FQ37', ylabel='count'>

# %%
plt.figure(figsize=(10,8),dpi=80)
sns.countplot(x ='age', hue ='FQ13', data = all_data)
plt.xticks(rotation=90)
for ax in plt.gcf().axes:
    l = ax.get_xlabel()
    ax.set_xlabel(l, fontsize=15)
plt.show()

#sns.set_title('Borrowed money for health/medical purposes in the last 12 months')

# %%
sns.relplot(x= "FQ31",y= "FQ20", data=all_data)

# %%
# the age of those with a bank account
plt.figure(figsize=(10,8),dpi=80)
sns.lineplot(data=all_data, x="age", y="FQ37")
# Out:
# <AxesSubplot:xlabel='age', ylabel='FQ37'>

# %%
# those who have a bank account and a mobile fone
plt.figure(figsize=(10,8),dpi=80)
sns.lineplot(data=all_data, x="FQ37", y="FQ33")
# Out:
# <AxesSubplot:xlabel='FQ37', ylabel='FQ33'>

# %%
# those whose bank account are active and suggest mobile banking
sns.lineplot(data=all_data, x="FQ37", y="FQ20")
# Out:
# <AxesSubplot:xlabel='FQ37', ylabel='FQ20'>

# %%
all_data.head()
# Out:
#    region   age  FQ1       FQ2       FQ3  FQ4       FQ5       FQ6       FQ7  \
# 0       6  35.0    2  1.063282  1.000000    2  1.159346  1.000000  1.000000
# 1       7  70.0    2  1.063282  1.298905    2  1.159346  1.223474  1.000000
# 2       7  22.0    2  1.000000  1.298905    2  1.159346  1.223474  1.000000
# 3       3  27.0    1  1.063282  1.298905    2  1.159346  2.000000  1.206857
# 4       0  79.0    2  1.063282  1.298905    2  1.159346  1.223474  1.206857
#
#    FQ8  ...  FQ20      FQ21  FQ22  FQ23  FQ30  FQ31  FQ33  FQ34  FQ37  Target
# 0    2  ...   2.0  1.000000     1     2   2.0   1.0   1.0   1.0     0     0.0
# 1    2  ...   2.0  1.000000     1     2   2.0   1.0   1.0   2.0     0     0.0
# 2    2  ...   2.0  2.000000     1     2   2.0   1.0   2.0   1.0     1     0.0
# 3    2  ...   1.0  1.784154     1     2   2.0   1.0   1.0   1.0     1     0.0
# 4    2  ...   2.0  2.000000     1     1   2.0   1.0   1.0   1.0     1     0.0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Preprocessing and training the data

# %%
# Applying one-hot encoding to Q23
from sklearn.preprocessing import OneHotEncoder

dummies_1 = pd.get_dummies(all_data["FQ23"], prefix="FQ23")

# %%
dummies_1.shape
# Out:
# (154923, 4)

# %%
all_data_1 = pd.concat([all_data, dummies_1], axis=1)

# %%
all_data_1.shape
# Out:
# (154923, 35)

# %%
all_data_1.drop(columns="FQ23", inplace=True)

# %%
dummies_1.shape
# Out:
# (154923, 4)

# %%
# Applying one-hot encoding to Q7
from sklearn.preprocessing import OneHotEncoder

dummies_2 = pd.get_dummies(all_data["FQ7"], prefix="FQ7")

# %%
all_data_2 = pd.concat([all_data, dummies_2], axis=1)

# %%
all_data_2.shape
# Out:
# (154923, 36)

# %%
all_data_2.drop(columns="FQ7", inplace=True)

# %%
# Applying one-hot encoding to age
from sklearn.preprocessing import OneHotEncoder

dummies_3 = pd.get_dummies(all_data["age"], prefix="age")

# %%
dummies_3.shape
# Out:
# (154923, 85)

# %%
all_data_3 = pd.concat([all_data, dummies_3], axis=1)

# %%
all_data_3.shape
# Out:
# (154923, 116)

# %%
all_data_3.drop(columns="age", inplace=True)

# %%
all_data.shape
# Out:
# (154923, 31)

# %%
all_data.describe()
# Out:
#               region            age            FQ1            FQ2  \
# count  154923.000000  154923.000000  154923.000000  154923.000000
# mean        2.897175      41.807569       1.562609       1.063282
# std         2.285400      17.897728       0.529573       0.192704
# min        -1.000000      15.000000       1.000000       1.000000
# 25%         1.000000      27.000000       1.000000       1.000000
# 50%         3.000000      39.000000       2.000000       1.063282
# 75%         4.000000      55.000000       2.000000       1.063282
# max         7.000000      99.000000       4.000000       4.000000
#
#                  FQ3            FQ4            FQ5            FQ6  \
# count  154923.000000  154923.000000  154923.000000  154923.000000
# mean        1.298905       1.824597       1.159346       1.223474
# std         0.305934       0.436026       0.168101       0.336088
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
#splitting into training and testing sets
y = train_data["Target"].values

# %%
y.shape
# Out:
# (108446,)

# %%
# Check for the split
all_data.shape
# Out:
# (154923, 31)

# %%
train_use = all_data.iloc[0:train_data.shape[0], :]

# %%
train_use.shape
# Out:
# (108446, 31)

# %%
X = train_use.values

# %%
test_use =all_data.iloc[train_data.shape[0]:, :]

# %%
test_use.shape
# Out:
# (46477, 31)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.15)

# %% [markdown]
# # Modelling using Naive Bayes

# %%
# Fitting Naive Bayes to the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB() # Instantiate the object
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)

# %%
y_submission = classifier.predict(test_use)

# %%
# evaluating performance : Accuracy, Precision, Recall
from sklearn import metrics

# print("Accuracy: ", metrics.accuracy_score(y_test, y_pred))
print("Precision: ", metrics.precision_score(y_test, y_pred))
print("Recall: ", metrics.recall_score(y_test, y_pred))
print("F1 Score: ", metrics.f1_score(y_test, y_pred))
# Out:
# Precision:  1.0
# Recall:  1.0
# F1 Score:  1.0

# %%
submission = pd.read_csv('SampleSubmission.csv', index_col=False)

# %%
submission.head()
# Out:
#             ID  Target
# 0  ID_000YI58E     NaN
# 1  ID_001SP4JF     NaN
# 2  ID_001VOF6S     NaN
# 3  ID_0030LULG     NaN
# 4  ID_0037PZ3R     NaN

# %%
submission["Target"] = y_submission

# %%
submission.head()
# Out:
#             ID  Target
# 0  ID_000YI58E       0
# 1  ID_001SP4JF       0
# 2  ID_001VOF6S       0
# 3  ID_0030LULG       0
# 4  ID_0037PZ3R       0

# %%
submission.shape
# Out:
# (46477, 2)

# %%
submission.to_csv("submission_1.csv", index=False)

# %%
from sklearn import preprocessing
from sklearn import utils
lab_enc = preprocessing.LabelEncoder()
y_train_encoded = lab_enc.fit_transform(y_train)
print(y_train_encoded)
print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(y_train.astype('int')))
print(utils.multiclass.type_of_target(y_train_encoded))
# Out:
# [0 0 0 ... 0 1 0]
# binary
# binary
# binary

# %% [markdown]
# # Modelling using RandomForest

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a RadomForest Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train_encoded)

y_predict =clf.predict(X_test)

# %%
y_submission2 = clf.predict(test_use)

# %%
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
# print("Accuracy: ", metrics.accuracy_score(y_test, y_predict))
print("Precision2: ", metrics.precision_score(y_test, y_predict))
print("Recall2: ",    metrics.recall_score(y_test, y_predict))
print("F1 Score2: ",  metrics.f1_score(y_test, y_predict))
# Out:
# Precision2:  1.0
# Recall2:  1.0
# F1 Score2:  1.0

# %%
submission_2 = pd.read_csv('SampleSubmission.csv', index_col=False)

# %%
submission_2.head()
# Out:
#             ID  Target
# 0  ID_000YI58E     NaN
# 1  ID_001SP4JF     NaN
# 2  ID_001VOF6S     NaN
# 3  ID_0030LULG     NaN
# 4  ID_0037PZ3R     NaN

# %%
submission_2["Target"] = y_submission2

# %%
submission_2.head()
# Out:
#             ID  Target
# 0  ID_000YI58E       0
# 1  ID_001SP4JF       0
# 2  ID_001VOF6S       0
# 3  ID_0030LULG       0
# 4  ID_0037PZ3R       0

# %%
submission_2.to_csv("submission_2.csv", index=False)

# %% [markdown]
# # Modelling Using Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred3 = clf.predict(X_test)

# %%
y_submission3 = clf.predict(test_use)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy3:",metrics.accuracy_score(y_test, y_pred3))
# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision3:",metrics.precision_score(y_test, y_pred3))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall3:",metrics.recall_score(y_test, y_pred3))
print("F1 Score3: ",  metrics.f1_score(y_test, y_pred3))
# Out:
# Accuracy3: 1.0
# Precision3: 1.0
# Recall3: 1.0
# F1 Score3:  1.0

# %%
submission_3 = pd.read_csv('SampleSubmission.csv', index_col=False)

# %%
submission_3.head()
# Out:
#             ID  Target
# 0  ID_000YI58E     NaN
# 1  ID_001SP4JF     NaN
# 2  ID_001VOF6S     NaN
# 3  ID_0030LULG     NaN
# 4  ID_0037PZ3R     NaN

# %%
submission_3["Target"] = y_submission3

# %%
submission_3.to_csv("submission_3.csv", index=False)

# %% [markdown]
# # Modelling Using Support Vector Machine

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred4 = clf.predict(X_test)

# %%
y_submission4 = clf.predict(test_use)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy4:",metrics.accuracy_score(y_test, y_pred4))
# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision4:",metrics.precision_score(y_test, y_pred4))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall4:",metrics.recall_score(y_test, y_pred4))
print("F1 Score4: ",  metrics.f1_score(y_test, y_pred4))
# Out:
# Accuracy4: 1.0
# Precision4: 1.0
# Recall4: 1.0
# F1 Score4:  1.0

# %%
submission_4 = pd.read_csv('SampleSubmission.csv', index_col=False)

# %%
submission_4.head()
# Out:
#             ID  Target
# 0  ID_000YI58E     NaN
# 1  ID_001SP4JF     NaN
# 2  ID_001VOF6S     NaN
# 3  ID_0030LULG     NaN
# 4  ID_0037PZ3R     NaN

# %%
submission_4["Target"] = y_submission4

# %%
submission_4.to_csv("submission_4.csv", index=False)
